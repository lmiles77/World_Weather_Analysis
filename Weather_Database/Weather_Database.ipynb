# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
cities
# Out:
# ['busselton',
#  'kruisfontein',
#  'hermanus',
#  'hendijan',
#  'yagunovskiy',
#  'brae',
#  'kapaa',
#  'kununurra',
#  'mataura',
#  'san patricio',
#  'bambous virieux',
#  'airai',
#  'toliary',
#  'bredasdorp',
#  'faanui',
#  'barrow',
#  'rikitea',
#  'souillac',
#  'fare',
#  'keflavik',
#  'illoqqortoormiut',
#  'sentyabrskiy',
#  'mys shmidta',
#  'husavik',
#  'grindavik',
#  'conde',
#  'namatanai',
#  'tigwi',
#  'uarini',
#  'burnie',
#  'vaini',
#  'avarua',
#  'punta arenas',
#  'unye',
#  'alice springs',
#  'ushuaia',
#  'anta',
#  'byron bay',
#  'cidreira',
#  'san cristobal',
#  'sitka',
#  'kangaatsiaq',
#  'loandjili',
#  'kavieng',
#  'carnarvon',
#  'yermish',
#  'teguldet',
#  'buala',
#  'palabuhanratu',
#  'zatoka',
#  'dikson',
#  'port lincoln',
#  'martapura',
#  'hobart',
#  'ngunguru',
#  'butaritari',
#  'half moon bay',
#  'kalmunai',
#  'saint-pierre',
#  'jamestown',
#  'leh',
#  'tasiilaq',
#  'puerto ayora',
#  'taoudenni',
#  'taolanaro',
#  'ayios nikolaos',
#  'port elizabeth',
#  'acajutla',
#  'cape town',
#  'kupang',
#  'clyde river',
#  'nikolskoye',
#  'belushya guba',
#  'kaitangata',
#  'mangrol',
#  'san quintin',
#  'constitucion',
#  'bluff',
#  'hasaki',
#  'zhanaozen',
#  'esmeraldas',
#  'gijon',
#  'lushunkou',
#  'yunjinghong',
#  'nuuk',
#  'fortuna',
#  'yantzaza',
#  'hare bay',
#  'rocha',
#  'sistranda',
#  'portland',
#  'port alfred',
#  'san juan bautista',
#  'yellowknife',
#  'georgetown',
#  'massakory',
#  'antropovo',
#  'atuona',
#  'bologoye',
#  'qurayyat',
#  'qabis',
#  'zyryanovsk',
#  'tsiroanomandidy',
#  'pattani',
#  'talnakh',
#  'new iberia',
#  'hilo',
#  'sur',
#  'marrakesh',
#  'new norfolk',
#  'mmathubudukwane',
#  'grand-santi',
#  'bathsheba',
#  'port keats',
#  'mount gambier',
#  'albany',
#  'pohrebyshche',
#  'shimoda',
#  'nuoro',
#  'esperance',
#  'cabo san lucas',
#  'tiksi',
#  'bethel',
#  'kahului',
#  'kendari',
#  'ust-nera',
#  'los lunas',
#  'traverse city',
#  'cockburn town',
#  'arinos',
#  'preobrazheniye',
#  'mar del plata',
#  'luderitz',
#  'winton',
#  'price',
#  'kita',
#  'lorengau',
#  'te anau',
#  'barzas',
#  'berlevag',
#  'egvekinot',
#  'ponta do sol',
#  'saveh',
#  'maiduguri',
#  'camacha',
#  'tautira',
#  'vallenar',
#  'saint-philippe',
#  'teluk nibung',
#  'lebu',
#  'kubuta',
#  'vila velha',
#  'mendi',
#  'vermilion',
#  'college',
#  'coihaique',
#  'batticaloa',
#  'plettenberg bay',
#  'saint-augustin',
#  'varna',
#  'upernavik',
#  'flinders',
#  'cabedelo',
#  'lompoc',
#  'east london',
#  'salinopolis',
#  'shenkursk',
#  'blagodatnoye',
#  'pisco',
#  'kloulklubed',
#  'samusu',
#  'victoria',
#  'saskylakh',
#  'alotau',
#  'tuktoyaktuk',
#  'bundaberg',
#  'penzance',
#  'yar-sale',
#  'gorontalo',
#  'rongcheng',
#  'sovetskaya gavan',
#  'rio de janeiro',
#  'paradwip',
#  'ribeira grande',
#  'kodiak',
#  'chokurdakh',
#  'torbay',
#  'zhukovo',
#  'beihai',
#  'chapais',
#  'vaitupu',
#  'klaksvik',
#  'songjianghe',
#  'mahebourg',
#  'thompson',
#  'sola',
#  'dingle',
#  'ust-maya',
#  'hithadhoo',
#  'baherden',
#  'tevaitoa',
#  'comodoro rivadavia',
#  'araouane',
#  'attawapiskat',
#  'qaanaaq',
#  'marzuq',
#  'severo-kurilsk',
#  'leningradskiy',
#  'petropavlovsk-kamchatskiy',
#  'tsihombe',
#  'maldonado',
#  'olafsvik',
#  'dipkarpaz',
#  'huarmey',
#  'dvinskoy',
#  'bendigo',
#  'gualaca',
#  'dolores',
#  'gushikawa',
#  'aswan',
#  'sorland',
#  'karratha',
#  'brockville',
#  'codrington',
#  'galchino',
#  'gallup',
#  'ahuimanu',
#  'mubi',
#  'tongzi',
#  'kysyl-syr',
#  'port hardy',
#  'liverpool',
#  'geraldton',
#  'kelheim',
#  'fairbanks',
#  'walvis bay',
#  'saldanha',
#  'pryazha',
#  'goderich',
#  'pitimbu',
#  'puerto colombia',
#  'khandyga',
#  'santa rosa',
#  'owando',
#  'nanortalik',
#  'lavrentiya',
#  'longyearbyen',
#  'arraial do cabo',
#  'ahipara',
#  'mullaitivu',
#  'marcona',
#  'barhi',
#  'tandil',
#  'castro',
#  'ambilobe',
#  'katsuura',
#  'nizwa',
#  'punta alta',
#  'margate',
#  'mumford',
#  'eravur',
#  'sobolevo',
#  'finnsnes',
#  'beira',
#  'cabinda',
#  'virginia beach',
#  'port augusta',
#  'springbok',
#  'waipawa',
#  'bam',
#  'balaipungut',
#  'mnogovershinnyy',
#  'narsaq',
#  'hamilton',
#  'hambantota',
#  'oriximina',
#  'surt',
#  'kieta',
#  'khatanga',
#  'komsomolskiy',
#  'jishou',
#  'piacabucu',
#  'labuhan',
#  'grootfontein',
#  'chimore',
#  'moba',
#  'doha',
#  'lahij',
#  'port hedland',
#  'aklavik',
#  'naze',
#  'kingston',
#  'doka',
#  'sorvag',
#  'saint george',
#  'paamiut',
#  'waiouru',
#  'baependi',
#  'sassandra',
#  'hervey bay',
#  'aykhal',
#  'lisakovsk',
#  'merauke',
#  'neiafu',
#  'suslovo',
#  'katsiveli',
#  'asyut',
#  'dumitra',
#  'fukue',
#  'amderma',
#  'ninghai',
#  'yangjiang',
#  'starobaltachevo',
#  'oudtshoorn',
#  'rawlins',
#  'kisangani',
#  'salalah',
#  'tanout',
#  'aksarka',
#  'bardiyah',
#  'lungesti',
#  'gazanjyk',
#  'santa isabel do rio negro',
#  'bengkulu',
#  'homer',
#  'reconquista',
#  'biltine',
#  'carutapera',
#  'satitoa',
#  'moose factory',
#  'tiznit',
#  'haines junction',
#  'morondava',
#  'sibu',
#  'porto walter',
#  'akdepe',
#  'waingapu',
#  'kachiry',
#  'pangnirtung',
#  'wairoa',
#  'fort nelson',
#  'lufilufi',
#  'hualmay',
#  'gorno-chuyskiy',
#  'touros',
#  'ixtapa',
#  'kota belud',
#  'matca',
#  'chernyshevskiy',
#  'norman wells',
#  'biak',
#  'jalu',
#  'porto novo',
#  'lusambo',
#  'oloron-sainte-marie',
#  'alyangula',
#  'of',
#  'chuy',
#  'ancud',
#  'ilulissat',
#  'anju',
#  'cherskiy',
#  'mahibadhoo',
#  'richards bay',
#  'vestmannaeyjar',
#  'socorro',
#  'lillooet',
#  'marsh harbour',
#  'jerome',
#  'rafai',
#  'yambio',
#  'ternate',
#  'granada',
#  'tangzhai',
#  'barentsburg',
#  'tuatapere',
#  'abha',
#  'dunedin',
#  'dzaoudzi',
#  'phalaborwa',
#  'lagoa',
#  'sedelnikovo',
#  'padang',
#  'mount isa',
#  'lyuban',
#  'ponta delgada',
#  'sabang',
#  'ketchikan',
#  'beloha',
#  'celestun',
#  'meulaboh',
#  'moanda',
#  'gurgan',
#  'port-cartier',
#  'whitley bay',
#  'asau',
#  'beringovskiy',
#  'yoichi',
#  'impfondo',
#  'nobres',
#  'youghal',
#  'rio grande',
#  'rusape',
#  'teruel',
#  'gravelbourg',
#  'chalon-sur-saone',
#  'takhli',
#  'sirjan',
#  'arlit',
#  'freudenberg',
#  'edd',
#  'suez',
#  'westport',
#  'suntar',
#  'ornskoldsvik',
#  'urumqi',
#  'svetlaya',
#  'vao',
#  'toribio',
#  'bonavista',
#  'kathmandu',
#  'bukama',
#  'sao filipe',
#  'mehamn',
#  'la ronge',
#  'labuan',
#  'coalcoman',
#  'nguiu',
#  'macheng',
#  'saidpur',
#  'rungata',
#  'basildon',
#  'payo',
#  'manggar',
#  'yulara',
#  'broken hill',
#  'show low',
#  'port macquarie',
#  'havoysund',
#  'the valley',
#  'tumannyy',
#  'sambava',
#  'yarkovo',
#  'vasilyevo',
#  'pevek',
#  'babanusah',
#  'dese',
#  'abengourou',
#  'shingu',
#  'yamada',
#  'talcahuano',
#  'voykove',
#  'yorosso',
#  'luba',
#  'el alto',
#  'mandalgovi',
#  'santa maria',
#  'santa cruz del sur',
#  'solon',
#  'guerrero negro',
#  'praya',
#  'veraval',
#  'beisfjord',
#  'galgani',
#  'luwuk',
#  'valleyview',
#  'alofi',
#  'ivdel',
#  'salihli',
#  'bakchar',
#  'qandahar',
#  'kattivakkam',
#  'kaeo',
#  'mattru',
#  'miranda',
#  'bereda',
#  'waconia',
#  'alihe',
#  'ekhabi',
#  'alta floresta',
#  'dianalund',
#  'okhotsk',
#  'mugur-aksy',
#  'pimentel',
#  'nabire',
#  'guanare',
#  'cayenne',
#  'lisala',
#  'swan hill',
#  'ozgon',
#  'zemio',
#  'iqaluit',
#  'nanchang',
#  'lahaina',
#  'tobermory',
#  'paramonga',
#  'candawaga',
#  'peniche',
#  'saryshagan',
#  'andros town',
#  'zhigansk',
#  'shafranovo',
#  'christchurch',
#  'ures',
#  'tarudant',
#  'mareeba',
#  'saleaula',
#  'freeport',
#  'karaul',
#  'coquimbo',
#  'dongsheng',
#  'chunoyar',
#  'tateyama',
#  'san julian',
#  'san rafael',
#  'sept-iles',
#  'sainte-suzanne',
#  'omboue',
#  'uusikaupunki',
#  'waddan',
#  'kutum',
#  'karamea',
#  'tahta',
#  'mata',
#  'bow island',
#  'macaboboni',
#  'leeton',
#  'pechora',
#  'derzhavinsk',
#  'olinda',
#  'hammerfest',
#  'novosineglazovskiy',
#  'palu',
#  'ambulu',
#  'lidzbark warminski',
#  'prosec',
#  'buin',
#  'taltal',
#  'srednekolymsk',
#  'guabito',
#  'hyeres',
#  'haimen',
#  'talesh',
#  'rochegda',
#  'grand centre',
#  'turayf',
#  'krasnyy chikoy',
#  'champerico',
#  'laurel',
#  'umm kaddadah',
#  'mezhdurechenskiy',
#  'aporawan',
#  'staraya toropa',
#  'cahokia',
#  'lata',
#  'azamgarh',
#  'nizhneyansk',
#  'am timan',
#  'mehran',
#  'gura sutii',
#  'laguna',
#  'korla',
#  'santa cruz',
#  'trelew',
#  'broome',
#  'inirida',
#  'warqla',
#  'sao joao dos patos',
#  'uruana',
#  'winnipeg',
#  'takoradi',
#  'benguela',
#  'grand river south east',
#  'scarborough',
#  'rivadavia',
#  'powell river',
#  'lara',
#  'annamalainagar',
#  'inverell',
#  'caravelas',
#  'abalak',
#  'zakamensk',
#  'ngukurr',
#  'awbari',
#  'pacific grove',
#  'mount pleasant',
#  'vanderhoof',
#  'kalga',
#  'palasa',
#  'zyryanka',
#  'hvide sande',
#  'gimli',
#  'sorong',
#  'cairns',
#  'valdivia',
#  'makakilo city',
#  'north bend',
#  'novochernorechenskiy',
#  'laguna de perlas',
#  'djibo',
#  'muros',
#  'honningsvag',
#  'bargal',
#  'enshi',
#  'bivolari',
#  'yenangyaung',
#  'isangel',
#  'adrar',
#  'los llanos de aridane',
#  'mirante do paranapanema',
#  'mergui',
#  'kabare',
#  'parral',
#  'klyuchi',
#  'banjar',
#  'suleya',
#  'medicine hat',
#  'avera',
#  'tilichiki',
#  'sibolga',
#  'boralday',
#  'cap malheureux',
#  'mino',
#  'naerbo',
#  'matara',
#  'itapeva',
#  'zuwarah',
#  'ipixuna',
#  'ayorou',
#  'necochea',
#  'kapoeta',
#  'ajdabiya',
#  'verkhnevilyuysk',
#  'maragogi',
#  'wolmaranstad',
#  'yeppoon',
#  'birin',
#  'dale',
#  'flin flon',
#  'yarmouth',
#  'arrifes',
#  'opoczno',
#  'zhicheng',
#  'abilene',
#  'abu samrah',
#  'chateau-thierry',
#  'staryy biser',
#  'sayyan',
#  'berberati',
#  'marawi',
#  'bonoua',
#  'mahadday weyne',
#  'namibe',
#  'ayan',
#  'hvolsvollur',
#  'susanville',
#  'babushkin',
#  'makkaveyevo',
#  'carbonia',
#  'atasu',
#  'black river',
#  'bandarbeyla',
#  'monrovia',
#  'raga',
#  'roxana',
#  'rumphi',
#  'krasnoselkup',
#  'arman',
#  'manado',
#  'doctor pedro p. pena',
#  'kropotkin',
#  'zumarraga',
#  'kapit',
#  'sarkand',
#  'pocatello',
#  'lubbock',
#  'kurumkan',
#  'kosino',
#  'barlinek',
#  'collie',
#  'mogadishu',
#  'sao joao da barra',
#  'kinsale',
#  'krasnoarmeysk',
#  'svetlyy',
#  'kiama',
#  'correntina',
#  'guantanamo',
#  'port-gentil',
#  'normandin',
#  'shieli',
#  'tabiauea',
#  'karkaralinsk',
#  'calama',
#  'tarancon',
#  'batagay-alyta',
#  'baruun-urt',
#  'ambovombe',
#  'tonantins',
#  'henties bay',
#  'bocas del toro',
#  'nehe',
#  'namwala',
#  'shelburne',
#  'batemans bay',
#  'wakkanai',
#  'tiarei',
#  'auki',
#  'vostok',
#  'faya',
#  'drinovci',
#  'longford',
#  'kilis',
#  'mayo',
#  'casa grande',
#  'lima',
#  'husum',
#  'sampit',
#  'mujiayingzi',
#  'gloversville',
#  'mailani',
#  'bari',
#  'kalangala',
#  'singaparna',
#  'muscat',
#  'glubokiy',
#  'malumfashi',
#  'mahajanga',
#  'kuandian',
#  'progreso',
#  'sibay',
#  'muravlenko',
#  'yekimovichi',
#  'prieska',
#  'kosonsoy',
#  'san pedro',
#  'le port',
#  'ilek',
#  'presidencia roque saenz pena',
#  'kalabo',
#  'zhangjiakou',
#  'prince rupert',
#  'nahan',
#  'lokosovo',
#  'sakaraha',
#  'yumen',
#  'republic',
#  'esna',
#  'karakendzha',
#  'khani',
#  'san ramon',
#  'manama',
#  'sayhat',
#  'horodnytsya',
#  'pundaguitan',
#  'yanchukan',
#  'kristiinankaupunki']

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "a005412dcb4ba8518483620dc944a9b5" 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a005412dcb4ba8518483620dc944a9b5

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

    
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather ["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : current_description})

# If an error is experienced, skip the city.
    except:
        #print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | busselton
# Processing Record 2 of Set 16 | kruisfontein
# Processing Record 3 of Set 16 | hermanus
# Processing Record 4 of Set 16 | hendijan
# Processing Record 5 of Set 16 | yagunovskiy
# Processing Record 6 of Set 16 | brae
# Processing Record 7 of Set 16 | kapaa
# Processing Record 8 of Set 16 | kununurra
# Processing Record 9 of Set 16 | mataura
# Processing Record 10 of Set 16 | san patricio
# Processing Record 11 of Set 16 | bambous virieux
# Processing Record 12 of Set 16 | airai
# Processing Record 13 of Set 16 | toliary
# Processing Record 14 of Set 16 | bredasdorp
# Processing Record 15 of Set 16 | faanui
# Processing Record 16 of Set 16 | barrow
# Processing Record 17 of Set 16 | rikitea
# Processing Record 18 of Set 16 | souillac
# Processing Record 19 of Set 16 | fare
# Processing Record 20 of Set 16 | keflavik
# Processing Record 21 of Set 16 | illoqqortoormiut
# Processing Record 22 of Set 16 | sentyabrskiy
# Processing Record 23 of Set 16 | mys shmidta
# Processing Record 24 of Set 16 | husavik
# Processing Record 25 of Set 16 | grindavik
# Processing Record 26 of Set 16 | conde
# Processing Record 27 of Set 16 | namatanai
# Processing Record 28 of Set 16 | tigwi
# Processing Record 29 of Set 16 | uarini
# Processing Record 30 of Set 16 | burnie
# Processing Record 31 of Set 16 | vaini
# Processing Record 32 of Set 16 | avarua
# Processing Record 33 of Set 16 | punta arenas
# Processing Record 34 of Set 16 | unye
# Processing Record 35 of Set 16 | alice springs
# Processing Record 36 of Set 16 | ushuaia
# Processing Record 37 of Set 16 | anta
# Processing Record 38 of Set 16 | byron bay
# Processing Record 39 of Set 16 | cidreira
# Processing Record 40 of Set 16 | san cristobal
# Processing Record 41 of Set 16 | sitka
# Processing Record 42 of Set 16 | kangaatsiaq
# Processing Record 43 of Set 16 | loandjili
# Processing Record 44 of Set 16 | kavieng
# Processing Record 45 of Set 16 | carnarvon
# Processing Record 46 of Set 16 | yermish
# Processing Record 47 of Set 16 | teguldet
# Processing Record 48 of Set 16 | buala
# Processing Record 49 of Set 16 | palabuhanratu
# Processing Record 50 of Set 16 | zatoka
# Processing Record 1 of Set 17 | dikson
# Processing Record 2 of Set 17 | port lincoln
# Processing Record 3 of Set 17 | martapura
# Processing Record 4 of Set 17 | hobart
# Processing Record 5 of Set 17 | ngunguru
# Processing Record 6 of Set 17 | butaritari
# Processing Record 7 of Set 17 | half moon bay
# Processing Record 8 of Set 17 | kalmunai
# Processing Record 9 of Set 17 | saint-pierre
# Processing Record 10 of Set 17 | jamestown
# Processing Record 11 of Set 17 | leh
# Processing Record 12 of Set 17 | tasiilaq
# Processing Record 13 of Set 17 | puerto ayora
# Processing Record 14 of Set 17 | taoudenni
# Processing Record 15 of Set 17 | taolanaro
# Processing Record 16 of Set 17 | ayios nikolaos
# Processing Record 17 of Set 17 | port elizabeth
# Processing Record 18 of Set 17 | acajutla
# Processing Record 19 of Set 17 | cape town
# Processing Record 20 of Set 17 | kupang
# Processing Record 21 of Set 17 | clyde river
# Processing Record 22 of Set 17 | nikolskoye
# Processing Record 23 of Set 17 | belushya guba
# Processing Record 24 of Set 17 | kaitangata
# Processing Record 25 of Set 17 | mangrol
# Processing Record 26 of Set 17 | san quintin
# Processing Record 27 of Set 17 | constitucion
# Processing Record 28 of Set 17 | bluff
# Processing Record 29 of Set 17 | hasaki
# Processing Record 30 of Set 17 | zhanaozen
# Processing Record 31 of Set 17 | esmeraldas
# Processing Record 32 of Set 17 | gijon
# Processing Record 33 of Set 17 | lushunkou
# Processing Record 34 of Set 17 | yunjinghong
# Processing Record 35 of Set 17 | nuuk
# Processing Record 36 of Set 17 | fortuna
# Processing Record 37 of Set 17 | yantzaza
# Processing Record 38 of Set 17 | hare bay
# Processing Record 39 of Set 17 | rocha
# Processing Record 40 of Set 17 | sistranda
# Processing Record 41 of Set 17 | portland
# Processing Record 42 of Set 17 | port alfred
# Processing Record 43 of Set 17 | san juan bautista
# Processing Record 44 of Set 17 | yellowknife
# Processing Record 45 of Set 17 | georgetown
# Processing Record 46 of Set 17 | massakory
# Processing Record 47 of Set 17 | antropovo
# Processing Record 48 of Set 17 | atuona
# Processing Record 49 of Set 17 | bologoye
# Processing Record 50 of Set 17 | qurayyat
# Processing Record 1 of Set 18 | qabis
# Processing Record 2 of Set 18 | zyryanovsk
# Processing Record 3 of Set 18 | tsiroanomandidy
# Processing Record 4 of Set 18 | pattani
# Processing Record 5 of Set 18 | talnakh
# Processing Record 6 of Set 18 | new iberia
# Processing Record 7 of Set 18 | hilo
# Processing Record 8 of Set 18 | sur
# Processing Record 9 of Set 18 | marrakesh
# Processing Record 10 of Set 18 | new norfolk
# Processing Record 11 of Set 18 | mmathubudukwane
# Processing Record 12 of Set 18 | grand-santi
# Processing Record 13 of Set 18 | bathsheba
# Processing Record 14 of Set 18 | port keats
# Processing Record 15 of Set 18 | mount gambier
# Processing Record 16 of Set 18 | albany
# Processing Record 17 of Set 18 | pohrebyshche
# Processing Record 18 of Set 18 | shimoda
# Processing Record 19 of Set 18 | nuoro
# Processing Record 20 of Set 18 | esperance
# Processing Record 21 of Set 18 | cabo san lucas
# Processing Record 22 of Set 18 | tiksi
# Processing Record 23 of Set 18 | bethel
# Processing Record 24 of Set 18 | kahului
# Processing Record 25 of Set 18 | kendari
# Processing Record 26 of Set 18 | ust-nera
# Processing Record 27 of Set 18 | los lunas
# Processing Record 28 of Set 18 | traverse city
# Processing Record 29 of Set 18 | cockburn town
# Processing Record 30 of Set 18 | arinos
# Processing Record 31 of Set 18 | preobrazheniye
# Processing Record 32 of Set 18 | mar del plata
# Processing Record 33 of Set 18 | luderitz
# Processing Record 34 of Set 18 | winton
# Processing Record 35 of Set 18 | price
# Processing Record 36 of Set 18 | kita
# Processing Record 37 of Set 18 | lorengau
# Processing Record 38 of Set 18 | te anau
# Processing Record 39 of Set 18 | barzas
# Processing Record 40 of Set 18 | berlevag
# Processing Record 41 of Set 18 | egvekinot
# Processing Record 42 of Set 18 | ponta do sol
# Processing Record 43 of Set 18 | saveh
# Processing Record 44 of Set 18 | maiduguri
# Processing Record 45 of Set 18 | camacha
# Processing Record 46 of Set 18 | tautira
# Processing Record 47 of Set 18 | vallenar
# Processing Record 48 of Set 18 | saint-philippe
# Processing Record 49 of Set 18 | teluk nibung
# Processing Record 50 of Set 18 | lebu
# Processing Record 1 of Set 19 | kubuta
# Processing Record 2 of Set 19 | vila velha
# Processing Record 3 of Set 19 | mendi
# Processing Record 4 of Set 19 | vermilion
# Processing Record 5 of Set 19 | college
# Processing Record 6 of Set 19 | coihaique
# Processing Record 7 of Set 19 | batticaloa
# Processing Record 8 of Set 19 | plettenberg bay
# Processing Record 9 of Set 19 | saint-augustin
# Processing Record 10 of Set 19 | varna
# Processing Record 11 of Set 19 | upernavik
# Processing Record 12 of Set 19 | flinders
# Processing Record 13 of Set 19 | cabedelo
# Processing Record 14 of Set 19 | lompoc
# Processing Record 15 of Set 19 | east london
# Processing Record 16 of Set 19 | salinopolis
# Processing Record 17 of Set 19 | shenkursk
# Processing Record 18 of Set 19 | blagodatnoye
# Processing Record 19 of Set 19 | pisco
# Processing Record 20 of Set 19 | kloulklubed
# Processing Record 21 of Set 19 | samusu
# Processing Record 22 of Set 19 | victoria
# Processing Record 23 of Set 19 | saskylakh
# Processing Record 24 of Set 19 | alotau
# Processing Record 25 of Set 19 | tuktoyaktuk
# Processing Record 26 of Set 19 | bundaberg
# Processing Record 27 of Set 19 | penzance
# Processing Record 28 of Set 19 | yar-sale
# Processing Record 29 of Set 19 | gorontalo
# Processing Record 30 of Set 19 | rongcheng
# Processing Record 31 of Set 19 | sovetskaya gavan
# Processing Record 32 of Set 19 | rio de janeiro
# Processing Record 33 of Set 19 | paradwip
# Processing Record 34 of Set 19 | ribeira grande
# Processing Record 35 of Set 19 | kodiak
# Processing Record 36 of Set 19 | chokurdakh
# Processing Record 37 of Set 19 | torbay
# Processing Record 38 of Set 19 | zhukovo
# Processing Record 39 of Set 19 | beihai
# Processing Record 40 of Set 19 | chapais
# Processing Record 41 of Set 19 | vaitupu
# Processing Record 42 of Set 19 | klaksvik
# Processing Record 43 of Set 19 | songjianghe
# Processing Record 44 of Set 19 | mahebourg
# Processing Record 45 of Set 19 | thompson
# Processing Record 46 of Set 19 | sola
# Processing Record 47 of Set 19 | dingle
# Processing Record 48 of Set 19 | ust-maya
# Processing Record 49 of Set 19 | hithadhoo
# Processing Record 50 of Set 19 | baherden
# Processing Record 1 of Set 20 | tevaitoa
# Processing Record 2 of Set 20 | comodoro rivadavia
# Processing Record 3 of Set 20 | araouane
# Processing Record 4 of Set 20 | attawapiskat
# Processing Record 5 of Set 20 | qaanaaq
# Processing Record 6 of Set 20 | marzuq
# Processing Record 7 of Set 20 | severo-kurilsk
# Processing Record 8 of Set 20 | leningradskiy
# Processing Record 9 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 20 | tsihombe
# Processing Record 11 of Set 20 | maldonado
# Processing Record 12 of Set 20 | olafsvik
# Processing Record 13 of Set 20 | dipkarpaz
# Processing Record 14 of Set 20 | huarmey
# Processing Record 15 of Set 20 | dvinskoy
# Processing Record 16 of Set 20 | bendigo
# Processing Record 17 of Set 20 | gualaca
# Processing Record 18 of Set 20 | dolores
# Processing Record 19 of Set 20 | gushikawa
# Processing Record 20 of Set 20 | aswan
# Processing Record 21 of Set 20 | sorland
# Processing Record 22 of Set 20 | karratha
# Processing Record 23 of Set 20 | brockville
# Processing Record 24 of Set 20 | codrington
# Processing Record 25 of Set 20 | galchino
# Processing Record 26 of Set 20 | gallup
# Processing Record 27 of Set 20 | ahuimanu
# Processing Record 28 of Set 20 | mubi
# Processing Record 29 of Set 20 | tongzi
# Processing Record 30 of Set 20 | kysyl-syr
# Processing Record 31 of Set 20 | port hardy
# Processing Record 32 of Set 20 | liverpool
# Processing Record 33 of Set 20 | geraldton
# Processing Record 34 of Set 20 | kelheim
# Processing Record 35 of Set 20 | fairbanks
# Processing Record 36 of Set 20 | walvis bay
# Processing Record 37 of Set 20 | saldanha
# Processing Record 38 of Set 20 | pryazha
# Processing Record 39 of Set 20 | goderich
# Processing Record 40 of Set 20 | pitimbu
# Processing Record 41 of Set 20 | puerto colombia
# Processing Record 42 of Set 20 | khandyga
# Processing Record 43 of Set 20 | santa rosa
# Processing Record 44 of Set 20 | owando
# Processing Record 45 of Set 20 | nanortalik
# Processing Record 46 of Set 20 | lavrentiya
# Processing Record 47 of Set 20 | longyearbyen
# Processing Record 48 of Set 20 | arraial do cabo
# Processing Record 49 of Set 20 | ahipara
# Processing Record 50 of Set 20 | mullaitivu
# Processing Record 1 of Set 21 | marcona
# Processing Record 2 of Set 21 | barhi
# Processing Record 3 of Set 21 | tandil
# Processing Record 4 of Set 21 | castro
# Processing Record 5 of Set 21 | ambilobe
# Processing Record 6 of Set 21 | katsuura
# Processing Record 7 of Set 21 | nizwa
# Processing Record 8 of Set 21 | punta alta
# Processing Record 9 of Set 21 | margate
# Processing Record 10 of Set 21 | mumford
# Processing Record 11 of Set 21 | eravur
# Processing Record 12 of Set 21 | sobolevo
# Processing Record 13 of Set 21 | finnsnes
# Processing Record 14 of Set 21 | beira
# Processing Record 15 of Set 21 | cabinda
# Processing Record 16 of Set 21 | virginia beach
# Processing Record 17 of Set 21 | port augusta
# Processing Record 18 of Set 21 | springbok
# Processing Record 19 of Set 21 | waipawa
# Processing Record 20 of Set 21 | bam
# Processing Record 21 of Set 21 | balaipungut
# Processing Record 22 of Set 21 | mnogovershinnyy
# Processing Record 23 of Set 21 | narsaq
# Processing Record 24 of Set 21 | hamilton
# Processing Record 25 of Set 21 | hambantota
# Processing Record 26 of Set 21 | oriximina
# Processing Record 27 of Set 21 | surt
# Processing Record 28 of Set 21 | kieta
# Processing Record 29 of Set 21 | khatanga
# Processing Record 30 of Set 21 | komsomolskiy
# Processing Record 31 of Set 21 | jishou
# Processing Record 32 of Set 21 | piacabucu
# Processing Record 33 of Set 21 | labuhan
# Processing Record 34 of Set 21 | grootfontein
# Processing Record 35 of Set 21 | chimore
# Processing Record 36 of Set 21 | moba
# Processing Record 37 of Set 21 | doha
# Processing Record 38 of Set 21 | lahij
# Processing Record 39 of Set 21 | port hedland
# Processing Record 40 of Set 21 | aklavik
# Processing Record 41 of Set 21 | naze
# Processing Record 42 of Set 21 | kingston
# Processing Record 43 of Set 21 | doka
# Processing Record 44 of Set 21 | sorvag
# Processing Record 45 of Set 21 | saint george
# Processing Record 46 of Set 21 | paamiut
# Processing Record 47 of Set 21 | waiouru
# Processing Record 48 of Set 21 | baependi
# Processing Record 49 of Set 21 | sassandra
# Processing Record 50 of Set 21 | hervey bay
# Processing Record 1 of Set 22 | aykhal
# Processing Record 2 of Set 22 | lisakovsk
# Processing Record 3 of Set 22 | merauke
# Processing Record 4 of Set 22 | neiafu
# Processing Record 5 of Set 22 | suslovo
# Processing Record 6 of Set 22 | katsiveli
# Processing Record 7 of Set 22 | asyut
# Processing Record 8 of Set 22 | dumitra
# Processing Record 9 of Set 22 | fukue
# Processing Record 10 of Set 22 | amderma
# Processing Record 11 of Set 22 | ninghai
# Processing Record 12 of Set 22 | yangjiang
# Processing Record 13 of Set 22 | starobaltachevo
# Processing Record 14 of Set 22 | oudtshoorn
# Processing Record 15 of Set 22 | rawlins
# Processing Record 16 of Set 22 | kisangani
# Processing Record 17 of Set 22 | salalah
# Processing Record 18 of Set 22 | tanout
# Processing Record 19 of Set 22 | aksarka
# Processing Record 20 of Set 22 | bardiyah
# Processing Record 21 of Set 22 | lungesti
# Processing Record 22 of Set 22 | gazanjyk
# Processing Record 23 of Set 22 | santa isabel do rio negro
# Processing Record 24 of Set 22 | bengkulu
# Processing Record 25 of Set 22 | homer
# Processing Record 26 of Set 22 | reconquista
# Processing Record 27 of Set 22 | biltine
# Processing Record 28 of Set 22 | carutapera
# Processing Record 29 of Set 22 | satitoa
# Processing Record 30 of Set 22 | moose factory
# Processing Record 31 of Set 22 | tiznit
# Processing Record 32 of Set 22 | haines junction
# Processing Record 33 of Set 22 | morondava
# Processing Record 34 of Set 22 | sibu
# Processing Record 35 of Set 22 | porto walter
# Processing Record 36 of Set 22 | akdepe
# Processing Record 37 of Set 22 | waingapu
# Processing Record 38 of Set 22 | kachiry
# Processing Record 39 of Set 22 | pangnirtung
# Processing Record 40 of Set 22 | wairoa
# Processing Record 41 of Set 22 | fort nelson
# Processing Record 42 of Set 22 | lufilufi
# Processing Record 43 of Set 22 | hualmay
# Processing Record 44 of Set 22 | gorno-chuyskiy
# Processing Record 45 of Set 22 | touros
# Processing Record 46 of Set 22 | ixtapa
# Processing Record 47 of Set 22 | kota belud
# Processing Record 48 of Set 22 | matca
# Processing Record 49 of Set 22 | chernyshevskiy
# Processing Record 50 of Set 22 | norman wells
# Processing Record 1 of Set 23 | biak
# Processing Record 2 of Set 23 | jalu
# Processing Record 3 of Set 23 | porto novo
# Processing Record 4 of Set 23 | lusambo
# Processing Record 5 of Set 23 | oloron-sainte-marie
# Processing Record 6 of Set 23 | alyangula
# Processing Record 7 of Set 23 | of
# Processing Record 8 of Set 23 | chuy
# Processing Record 9 of Set 23 | ancud
# Processing Record 10 of Set 23 | ilulissat
# Processing Record 11 of Set 23 | anju
# Processing Record 12 of Set 23 | cherskiy
# Processing Record 13 of Set 23 | mahibadhoo
# Processing Record 14 of Set 23 | richards bay
# Processing Record 15 of Set 23 | vestmannaeyjar
# Processing Record 16 of Set 23 | socorro
# Processing Record 17 of Set 23 | lillooet
# Processing Record 18 of Set 23 | marsh harbour
# Processing Record 19 of Set 23 | jerome
# Processing Record 20 of Set 23 | rafai
# Processing Record 21 of Set 23 | yambio
# Processing Record 22 of Set 23 | ternate
# Processing Record 23 of Set 23 | granada
# Processing Record 24 of Set 23 | tangzhai
# Processing Record 25 of Set 23 | barentsburg
# Processing Record 26 of Set 23 | tuatapere
# Processing Record 27 of Set 23 | abha
# Processing Record 28 of Set 23 | dunedin
# Processing Record 29 of Set 23 | dzaoudzi
# Processing Record 30 of Set 23 | phalaborwa
# Processing Record 31 of Set 23 | lagoa
# Processing Record 32 of Set 23 | sedelnikovo
# Processing Record 33 of Set 23 | padang
# Processing Record 34 of Set 23 | mount isa
# Processing Record 35 of Set 23 | lyuban
# Processing Record 36 of Set 23 | ponta delgada
# Processing Record 37 of Set 23 | sabang
# Processing Record 38 of Set 23 | ketchikan
# Processing Record 39 of Set 23 | beloha
# Processing Record 40 of Set 23 | celestun
# Processing Record 41 of Set 23 | meulaboh
# Processing Record 42 of Set 23 | moanda
# Processing Record 43 of Set 23 | gurgan
# Processing Record 44 of Set 23 | port-cartier
# Processing Record 45 of Set 23 | whitley bay
# Processing Record 46 of Set 23 | asau
# Processing Record 47 of Set 23 | beringovskiy
# Processing Record 48 of Set 23 | yoichi
# Processing Record 49 of Set 23 | impfondo
# Processing Record 50 of Set 23 | nobres
# Processing Record 1 of Set 24 | youghal
# Processing Record 2 of Set 24 | rio grande
# Processing Record 3 of Set 24 | rusape
# Processing Record 4 of Set 24 | teruel
# Processing Record 5 of Set 24 | gravelbourg
# Processing Record 6 of Set 24 | chalon-sur-saone
# Processing Record 7 of Set 24 | takhli
# Processing Record 8 of Set 24 | sirjan
# Processing Record 9 of Set 24 | arlit
# Processing Record 10 of Set 24 | freudenberg
# Processing Record 11 of Set 24 | edd
# Processing Record 12 of Set 24 | suez
# Processing Record 13 of Set 24 | westport
# Processing Record 14 of Set 24 | suntar
# Processing Record 15 of Set 24 | ornskoldsvik
# Processing Record 16 of Set 24 | urumqi
# Processing Record 17 of Set 24 | svetlaya
# Processing Record 18 of Set 24 | vao
# Processing Record 19 of Set 24 | toribio
# Processing Record 20 of Set 24 | bonavista
# Processing Record 21 of Set 24 | kathmandu
# Processing Record 22 of Set 24 | bukama
# Processing Record 23 of Set 24 | sao filipe
# Processing Record 24 of Set 24 | mehamn
# Processing Record 25 of Set 24 | la ronge
# Processing Record 26 of Set 24 | labuan
# Processing Record 27 of Set 24 | coalcoman
# Processing Record 28 of Set 24 | nguiu
# Processing Record 29 of Set 24 | macheng
# Processing Record 30 of Set 24 | saidpur
# Processing Record 31 of Set 24 | rungata
# Processing Record 32 of Set 24 | basildon
# Processing Record 33 of Set 24 | payo
# Processing Record 34 of Set 24 | manggar
# Processing Record 35 of Set 24 | yulara
# Processing Record 36 of Set 24 | broken hill
# Processing Record 37 of Set 24 | show low
# Processing Record 38 of Set 24 | port macquarie
# Processing Record 39 of Set 24 | havoysund
# Processing Record 40 of Set 24 | the valley
# Processing Record 41 of Set 24 | tumannyy
# Processing Record 42 of Set 24 | sambava
# Processing Record 43 of Set 24 | yarkovo
# Processing Record 44 of Set 24 | vasilyevo
# Processing Record 45 of Set 24 | pevek
# Processing Record 46 of Set 24 | babanusah
# Processing Record 47 of Set 24 | dese
# Processing Record 48 of Set 24 | abengourou
# Processing Record 49 of Set 24 | shingu
# Processing Record 50 of Set 24 | yamada
# Processing Record 1 of Set 25 | talcahuano
# Processing Record 2 of Set 25 | voykove
# Processing Record 3 of Set 25 | yorosso
# Processing Record 4 of Set 25 | luba
# Processing Record 5 of Set 25 | el alto
# Processing Record 6 of Set 25 | mandalgovi
# Processing Record 7 of Set 25 | santa maria
# Processing Record 8 of Set 25 | santa cruz del sur
# Processing Record 9 of Set 25 | solon
# Processing Record 10 of Set 25 | guerrero negro
# Processing Record 11 of Set 25 | praya
# Processing Record 12 of Set 25 | veraval
# Processing Record 13 of Set 25 | beisfjord
# Processing Record 14 of Set 25 | galgani
# Processing Record 15 of Set 25 | luwuk
# Processing Record 16 of Set 25 | valleyview
# Processing Record 17 of Set 25 | alofi
# Processing Record 18 of Set 25 | ivdel
# Processing Record 19 of Set 25 | salihli
# Processing Record 20 of Set 25 | bakchar
# Processing Record 21 of Set 25 | qandahar
# Processing Record 22 of Set 25 | kattivakkam
# Processing Record 23 of Set 25 | kaeo
# Processing Record 24 of Set 25 | mattru
# Processing Record 25 of Set 25 | miranda
# Processing Record 26 of Set 25 | bereda
# Processing Record 27 of Set 25 | waconia
# Processing Record 28 of Set 25 | alihe
# Processing Record 29 of Set 25 | ekhabi
# Processing Record 30 of Set 25 | alta floresta
# Processing Record 31 of Set 25 | dianalund
# Processing Record 32 of Set 25 | okhotsk
# Processing Record 33 of Set 25 | mugur-aksy
# Processing Record 34 of Set 25 | pimentel
# Processing Record 35 of Set 25 | nabire
# Processing Record 36 of Set 25 | guanare
# Processing Record 37 of Set 25 | cayenne
# Processing Record 38 of Set 25 | lisala
# Processing Record 39 of Set 25 | swan hill
# Processing Record 40 of Set 25 | ozgon
# Processing Record 41 of Set 25 | zemio
# Processing Record 42 of Set 25 | iqaluit
# Processing Record 43 of Set 25 | nanchang
# Processing Record 44 of Set 25 | lahaina
# Processing Record 45 of Set 25 | tobermory
# Processing Record 46 of Set 25 | paramonga
# Processing Record 47 of Set 25 | candawaga
# Processing Record 48 of Set 25 | peniche
# Processing Record 49 of Set 25 | saryshagan
# Processing Record 50 of Set 25 | andros town
# Processing Record 1 of Set 26 | zhigansk
# Processing Record 2 of Set 26 | shafranovo
# Processing Record 3 of Set 26 | christchurch
# Processing Record 4 of Set 26 | ures
# Processing Record 5 of Set 26 | tarudant
# Processing Record 6 of Set 26 | mareeba
# Processing Record 7 of Set 26 | saleaula
# Processing Record 8 of Set 26 | freeport
# Processing Record 9 of Set 26 | karaul
# Processing Record 10 of Set 26 | coquimbo
# Processing Record 11 of Set 26 | dongsheng
# Processing Record 12 of Set 26 | chunoyar
# Processing Record 13 of Set 26 | tateyama
# Processing Record 14 of Set 26 | san julian
# Processing Record 15 of Set 26 | san rafael
# Processing Record 16 of Set 26 | sept-iles
# Processing Record 17 of Set 26 | sainte-suzanne
# Processing Record 18 of Set 26 | omboue
# Processing Record 19 of Set 26 | uusikaupunki
# Processing Record 20 of Set 26 | waddan
# Processing Record 21 of Set 26 | kutum
# Processing Record 22 of Set 26 | karamea
# Processing Record 23 of Set 26 | tahta
# Processing Record 24 of Set 26 | mata
# Processing Record 25 of Set 26 | bow island
# Processing Record 26 of Set 26 | macaboboni
# Processing Record 27 of Set 26 | leeton
# Processing Record 28 of Set 26 | pechora
# Processing Record 29 of Set 26 | derzhavinsk
# Processing Record 30 of Set 26 | olinda
# Processing Record 31 of Set 26 | hammerfest
# Processing Record 32 of Set 26 | novosineglazovskiy
# Processing Record 33 of Set 26 | palu
# Processing Record 34 of Set 26 | ambulu
# Processing Record 35 of Set 26 | lidzbark warminski
# Processing Record 36 of Set 26 | prosec
# Processing Record 37 of Set 26 | buin
# Processing Record 38 of Set 26 | taltal
# Processing Record 39 of Set 26 | srednekolymsk
# Processing Record 40 of Set 26 | guabito
# Processing Record 41 of Set 26 | hyeres
# Processing Record 42 of Set 26 | haimen
# Processing Record 43 of Set 26 | talesh
# Processing Record 44 of Set 26 | rochegda
# Processing Record 45 of Set 26 | grand centre
# Processing Record 46 of Set 26 | turayf
# Processing Record 47 of Set 26 | krasnyy chikoy
# Processing Record 48 of Set 26 | champerico
# Processing Record 49 of Set 26 | laurel
# Processing Record 50 of Set 26 | umm kaddadah
# Processing Record 1 of Set 27 | mezhdurechenskiy
# Processing Record 2 of Set 27 | aporawan
# Processing Record 3 of Set 27 | staraya toropa
# Processing Record 4 of Set 27 | cahokia
# Processing Record 5 of Set 27 | lata
# Processing Record 6 of Set 27 | azamgarh
# Processing Record 7 of Set 27 | nizhneyansk
# Processing Record 8 of Set 27 | am timan
# Processing Record 9 of Set 27 | mehran
# Processing Record 10 of Set 27 | gura sutii
# Processing Record 11 of Set 27 | laguna
# Processing Record 12 of Set 27 | korla
# Processing Record 13 of Set 27 | santa cruz
# Processing Record 14 of Set 27 | trelew
# Processing Record 15 of Set 27 | broome
# Processing Record 16 of Set 27 | inirida
# Processing Record 17 of Set 27 | warqla
# Processing Record 18 of Set 27 | sao joao dos patos
# Processing Record 19 of Set 27 | uruana
# Processing Record 20 of Set 27 | winnipeg
# Processing Record 21 of Set 27 | takoradi
# Processing Record 22 of Set 27 | benguela
# Processing Record 23 of Set 27 | grand river south east
# Processing Record 24 of Set 27 | scarborough
# Processing Record 25 of Set 27 | rivadavia
# Processing Record 26 of Set 27 | powell river
# Processing Record 27 of Set 27 | lara
# Processing Record 28 of Set 27 | annamalainagar
# Processing Record 29 of Set 27 | inverell
# Processing Record 30 of Set 27 | caravelas
# Processing Record 31 of Set 27 | abalak
# Processing Record 32 of Set 27 | zakamensk
# Processing Record 33 of Set 27 | ngukurr
# Processing Record 34 of Set 27 | awbari
# Processing Record 35 of Set 27 | pacific grove
# Processing Record 36 of Set 27 | mount pleasant
# Processing Record 37 of Set 27 | vanderhoof
# Processing Record 38 of Set 27 | kalga
# Processing Record 39 of Set 27 | palasa
# Processing Record 40 of Set 27 | zyryanka
# Processing Record 41 of Set 27 | hvide sande
# Processing Record 42 of Set 27 | gimli
# Processing Record 43 of Set 27 | sorong
# Processing Record 44 of Set 27 | cairns
# Processing Record 45 of Set 27 | valdivia
# Processing Record 46 of Set 27 | makakilo city
# Processing Record 47 of Set 27 | north bend
# Processing Record 48 of Set 27 | novochernorechenskiy
# Processing Record 49 of Set 27 | laguna de perlas
# Processing Record 50 of Set 27 | djibo
# Processing Record 1 of Set 28 | muros
# Processing Record 2 of Set 28 | honningsvag
# Processing Record 3 of Set 28 | bargal
# Processing Record 4 of Set 28 | enshi
# Processing Record 5 of Set 28 | bivolari
# Processing Record 6 of Set 28 | yenangyaung
# Processing Record 7 of Set 28 | isangel
# Processing Record 8 of Set 28 | adrar
# Processing Record 9 of Set 28 | los llanos de aridane
# Processing Record 10 of Set 28 | mirante do paranapanema
# Processing Record 11 of Set 28 | mergui
# Processing Record 12 of Set 28 | kabare
# Processing Record 13 of Set 28 | parral
# Processing Record 14 of Set 28 | klyuchi
# Processing Record 15 of Set 28 | banjar
# Processing Record 38 of Set 29 | guantanamo
# Processing Record 39 of Set 29 | port-gentil
# Processing Record 40 of Set 29 | normandin
# Processing Record 41 of Set 29 | shieli
# Processing Record 42 of Set 29 | tabiauea
# Processing Record 43 of Set 29 | karkaralinsk
# Processing Record 44 of Set 29 | calama
# Processing Record 45 of Set 29 | tarancon
# Processing Record 46 of Set 29 | batagay-alyta
# Processing Record 47 of Set 29 | baruun-urt
# Processing Record 48 of Set 29 | ambovombe
# Processing Record 49 of Set 29 | tonantins
# Processing Record 50 of Set 29 | henties bay
# Processing Record 1 of Set 30 | bocas del toro
# Processing Record 2 of Set 30 | nehe
# Processing Record 3 of Set 30 | namwala
# Processing Record 4 of Set 30 | shelburne
# Processing Record 5 of Set 30 | batemans bay
# Processing Record 6 of Set 30 | wakkanai
# Processing Record 7 of Set 30 | tiarei
# Processing Record 8 of Set 30 | auki
# Processing Record 9 of Set 30 | vostok
# Processing Record 10 of Set 30 | faya
# Processing Record 11 of Set 30 | drinovci
# Processing Record 12 of Set 30 | longford
# Processing Record 13 of Set 30 | kilis
# Processing Record 14 of Set 30 | mayo
# Processing Record 15 of Set 30 | casa grande
# Processing Record 16 of Set 30 | lima
# Processing Record 17 of Set 30 | husum
# Processing Record 18 of Set 30 | sampit
# Processing Record 19 of Set 30 | mujiayingzi
# Processing Record 20 of Set 30 | gloversville
# Processing Record 21 of Set 30 | mailani
# Processing Record 22 of Set 30 | bari
# Processing Record 23 of Set 30 | kalangala
# Processing Record 24 of Set 30 | singaparna
# Processing Record 25 of Set 30 | muscat
# Processing Record 26 of Set 30 | glubokiy
# Processing Record 27 of Set 30 | malumfashi
# Processing Record 28 of Set 30 | mahajanga
# Processing Record 29 of Set 30 | kuandian
# Processing Record 30 of Set 30 | progreso
# Processing Record 31 of Set 30 | sibay
# Processing Record 32 of Set 30 | muravlenko
# Processing Record 33 of Set 30 | yekimovichi
# Processing Record 34 of Set 30 | prieska
# Processing Record 35 of Set 30 | kosonsoy
# Processing Record 36 of Set 30 | san pedro
# Processing Record 37 of Set 30 | le port
# Processing Record 38 of Set 30 | ilek
# Processing Record 39 of Set 30 | presidencia roque saenz pena
# Processing Record 40 of Set 30 | kalabo
# Processing Record 41 of Set 30 | zhangjiakou
# Processing Record 42 of Set 30 | prince rupert
# Processing Record 43 of Set 30 | nahan
# Processing Record 44 of Set 30 | lokosovo
# Processing Record 45 of Set 30 | sakaraha
# Processing Record 46 of Set 30 | yumen
# Processing Record 47 of Set 30 | republic
# Processing Record 48 of Set 30 | esna
# Processing Record 49 of Set 30 | karakendzha
# Processing Record 50 of Set 30 | khani
# Processing Record 1 of Set 31 | san ramon
# Processing Record 2 of Set 31 | manama
# Processing Record 3 of Set 31 | sayhat
# Processing Record 4 of Set 31 | horodnytsya
# Processing Record 5 of Set 31 | pundaguitan
# Processing Record 6 of Set 31 | yanchukan
# Processing Record 7 of Set 31 | kristiinankaupunki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
cities
# Out:
# ['busselton',
#  'kruisfontein',
#  'hermanus',
#  'hendijan',
#  'yagunovskiy',
#  'brae',
#  'kapaa',
#  'kununurra',
#  'mataura',
#  'san patricio',
#  'bambous virieux',
#  'airai',
#  'toliary',
#  'bredasdorp',
#  'faanui',
#  'barrow',
#  'rikitea',
#  'souillac',
#  'fare',
#  'keflavik',
#  'illoqqortoormiut',
#  'sentyabrskiy',
#  'mys shmidta',
#  'husavik',
#  'grindavik',
#  'conde',
#  'namatanai',
#  'tigwi',
#  'uarini',
#  'burnie',
#  'vaini',
#  'avarua',
#  'punta arenas',
#  'unye',
#  'alice springs',
#  'ushuaia',
#  'anta',
#  'byron bay',
#  'cidreira',
#  'san cristobal',
#  'sitka',
#  'kangaatsiaq',
#  'loandjili',
#  'kavieng',
#  'carnarvon',
#  'yermish',
#  'teguldet',
#  'buala',
#  'palabuhanratu',
#  'zatoka',
#  'dikson',
#  'port lincoln',
#  'martapura',
#  'hobart',
#  'ngunguru',
#  'butaritari',
#  'half moon bay',
#  'kalmunai',
#  'saint-pierre',
#  'jamestown',
#  'leh',
#  'tasiilaq',
#  'puerto ayora',
#  'taoudenni',
#  'taolanaro',
#  'ayios nikolaos',
#  'port elizabeth',
#  'acajutla',
#  'cape town',
#  'kupang',
#  'clyde river',
#  'nikolskoye',
#  'belushya guba',
#  'kaitangata',
#  'mangrol',
#  'san quintin',
#  'constitucion',
#  'bluff',
#  'hasaki',
#  'zhanaozen',
#  'esmeraldas',
#  'gijon',
#  'lushunkou',
#  'yunjinghong',
#  'nuuk',
#  'fortuna',
#  'yantzaza',
#  'hare bay',
#  'rocha',
#  'sistranda',
#  'portland',
#  'port alfred',
#  'san juan bautista',
#  'yellowknife',
#  'georgetown',
#  'massakory',
#  'antropovo',
#  'atuona',
#  'bologoye',
#  'qurayyat',
#  'qabis',
#  'zyryanovsk',
#  'tsiroanomandidy',
#  'pattani',
#  'talnakh',
#  'new iberia',
#  'hilo',
#  'sur',
#  'marrakesh',
#  'new norfolk',
#  'mmathubudukwane',
#  'grand-santi',
#  'bathsheba',
#  'port keats',
#  'mount gambier',
#  'albany',
#  'pohrebyshche',
#  'shimoda',
#  'nuoro',
#  'esperance',
#  'cabo san lucas',
#  'tiksi',
#  'bethel',
#  'kahului',
#  'kendari',
#  'ust-nera',
#  'los lunas',
#  'traverse city',
#  'cockburn town',
#  'arinos',
#  'preobrazheniye',
#  'mar del plata',
#  'luderitz',
#  'winton',
#  'price',
#  'kita',
#  'lorengau',
#  'te anau',
#  'barzas',
#  'berlevag',
#  'egvekinot',
#  'ponta do sol',
#  'saveh',
#  'maiduguri',
#  'camacha',
#  'tautira',
#  'vallenar',
#  'saint-philippe',
#  'teluk nibung',
#  'lebu',
#  'kubuta',
#  'vila velha',
#  'mendi',
#  'vermilion',
#  'college',
#  'coihaique',
#  'batticaloa',
#  'plettenberg bay',
#  'saint-augustin',
#  'varna',
#  'upernavik',
#  'flinders',
#  'cabedelo',
#  'lompoc',
#  'east london',
#  'salinopolis',
#  'shenkursk',
#  'blagodatnoye',
#  'pisco',
#  'kloulklubed',
#  'samusu',
#  'victoria',
#  'saskylakh',
#  'alotau',
#  'tuktoyaktuk',
#  'bundaberg',
#  'penzance',
#  'yar-sale',
#  'gorontalo',
#  'rongcheng',
#  'sovetskaya gavan',
#  'rio de janeiro',
#  'paradwip',
#  'ribeira grande',
#  'kodiak',
#  'chokurdakh',
#  'torbay',
#  'zhukovo',
#  'beihai',
#  'chapais',
#  'vaitupu',
#  'klaksvik',
#  'songjianghe',
#  'mahebourg',
#  'thompson',
#  'sola',
#  'dingle',
#  'ust-maya',
#  'hithadhoo',
#  'baherden',
#  'tevaitoa',
#  'comodoro rivadavia',
#  'araouane',
#  'attawapiskat',
#  'qaanaaq',
#  'marzuq',
#  'severo-kurilsk',
#  'leningradskiy',
#  'petropavlovsk-kamchatskiy',
#  'tsihombe',
#  'maldonado',
#  'olafsvik',
#  'dipkarpaz',
#  'huarmey',
#  'dvinskoy',
#  'bendigo',
#  'gualaca',
#  'dolores',
#  'gushikawa',
#  'aswan',
#  'sorland',
#  'karratha',
#  'brockville',
#  'codrington',
#  'galchino',
#  'gallup',
#  'ahuimanu',
#  'mubi',
#  'tongzi',
#  'kysyl-syr',
#  'port hardy',
#  'liverpool',
#  'geraldton',
#  'kelheim',
#  'fairbanks',
#  'walvis bay',
#  'saldanha',
#  'pryazha',
#  'goderich',
#  'pitimbu',
#  'puerto colombia',
#  'khandyga',
#  'santa rosa',
#  'owando',
#  'nanortalik',
#  'lavrentiya',
#  'longyearbyen',
#  'arraial do cabo',
#  'ahipara',
#  'mullaitivu',
#  'marcona',
#  'barhi',
#  'tandil',
#  'castro',
#  'ambilobe',
#  'katsuura',
#  'nizwa',
#  'punta alta',
#  'margate',
#  'mumford',
#  'eravur',
#  'sobolevo',
#  'finnsnes',
#  'beira',
#  'cabinda',
#  'virginia beach',
#  'port augusta',
#  'springbok',
#  'waipawa',
#  'bam',
#  'balaipungut',
#  'mnogovershinnyy',
#  'narsaq',
#  'hamilton',
#  'hambantota',
#  'oriximina',
#  'surt',
#  'kieta',
#  'khatanga',
#  'komsomolskiy',
#  'jishou',
#  'piacabucu',
#  'labuhan',
#  'grootfontein',
#  'chimore',
#  'moba',
#  'doha',
#  'lahij',
#  'port hedland',
#  'aklavik',
#  'naze',
#  'kingston',
#  'doka',
#  'sorvag',
#  'saint george',
#  'paamiut',
#  'waiouru',
#  'baependi',
#  'sassandra',
#  'hervey bay',
#  'aykhal',
#  'lisakovsk',
#  'merauke',
#  'neiafu',
#  'suslovo',
#  'katsiveli',
#  'asyut',
#  'dumitra',
#  'fukue',
#  'amderma',
#  'ninghai',
#  'yangjiang',
#  'starobaltachevo',
#  'oudtshoorn',
#  'rawlins',
#  'kisangani',
#  'salalah',
#  'tanout',
#  'aksarka',
#  'bardiyah',
#  'lungesti',
#  'gazanjyk',
#  'santa isabel do rio negro',
#  'bengkulu',
#  'homer',
#  'reconquista',
#  'biltine',
#  'carutapera',
#  'satitoa',
#  'moose factory',
#  'tiznit',
#  'haines junction',
#  'morondava',
#  'sibu',
#  'porto walter',
#  'akdepe',
#  'waingapu',
#  'kachiry',
#  'pangnirtung',
#  'wairoa',
#  'fort nelson',
#  'lufilufi',
#  'hualmay',
#  'gorno-chuyskiy',
#  'touros',
#  'ixtapa',
#  'kota belud',
#  'matca',
#  'chernyshevskiy',
#  'norman wells',
#  'biak',
#  'jalu',
#  'porto novo',
#  'lusambo',
#  'oloron-sainte-marie',
#  'alyangula',
#  'of',
#  'chuy',
#  'ancud',
#  'ilulissat',
#  'anju',
#  'cherskiy',
#  'mahibadhoo',
#  'richards bay',
#  'vestmannaeyjar',
#  'socorro',
#  'lillooet',
#  'marsh harbour',
#  'jerome',
#  'rafai',
#  'yambio',
#  'ternate',
#  'granada',
#  'tangzhai',
#  'barentsburg',
#  'tuatapere',
#  'abha',
#  'dunedin',
#  'dzaoudzi',
#  'phalaborwa',
#  'lagoa',
#  'sedelnikovo',
#  'padang',
#  'mount isa',
#  'lyuban',
#  'ponta delgada',
#  'sabang',
#  'ketchikan',
#  'beloha',
#  'celestun',
#  'meulaboh',
#  'moanda',
#  'gurgan',
#  'port-cartier',
#  'whitley bay',
#  'asau',
#  'beringovskiy',
#  'yoichi',
#  'impfondo',
#  'nobres',
#  'youghal',
#  'rio grande',
#  'rusape',
#  'teruel',
#  'gravelbourg',
#  'chalon-sur-saone',
#  'takhli',
#  'sirjan',
#  'arlit',
#  'freudenberg',
#  'edd',
#  'suez',
#  'westport',
#  'suntar',
#  'ornskoldsvik',
#  'urumqi',
#  'svetlaya',
#  'vao',
#  'toribio',
#  'bonavista',
#  'kathmandu',
#  'bukama',
#  'sao filipe',
#  'mehamn',
#  'la ronge',
#  'labuan',
#  'coalcoman',
#  'nguiu',
#  'macheng',
#  'saidpur',
#  'rungata',
#  'basildon',
#  'payo',
#  'manggar',
#  'yulara',
#  'broken hill',
#  'show low',
#  'port macquarie',
#  'havoysund',
#  'the valley',
#  'tumannyy',
#  'sambava',
#  'yarkovo',
#  'vasilyevo',
#  'pevek',
#  'babanusah',
#  'dese',
#  'abengourou',
#  'shingu',
#  'yamada',
#  'talcahuano',
#  'voykove',
#  'yorosso',
#  'luba',
#  'el alto',
#  'mandalgovi',
#  'santa maria',
#  'santa cruz del sur',
#  'solon',
#  'guerrero negro',
#  'praya',
#  'veraval',
#  'beisfjord',
#  'galgani',
#  'luwuk',
#  'valleyview',
#  'alofi',
#  'ivdel',
#  'salihli',
#  'bakchar',
#  'qandahar',
#  'kattivakkam',
#  'kaeo',
#  'mattru',
#  'miranda',
#  'bereda',
#  'waconia',
#  'alihe',
#  'ekhabi',
#  'alta floresta',
#  'dianalund',
#  'okhotsk',
#  'mugur-aksy',
#  'pimentel',
#  'nabire',
#  'guanare',
#  'cayenne',
#  'lisala',
#  'swan hill',
#  'ozgon',
#  'zemio',
#  'iqaluit',
#  'nanchang',
#  'lahaina',
#  'tobermory',
#  'paramonga',
#  'candawaga',
#  'peniche',
#  'saryshagan',
#  'andros town',
#  'zhigansk',
#  'shafranovo',
#  'christchurch',
#  'ures',
#  'tarudant',
#  'mareeba',
#  'saleaula',
#  'freeport',
#  'karaul',
#  'coquimbo',
#  'dongsheng',
#  'chunoyar',
#  'tateyama',
#  'san julian',
#  'san rafael',
#  'sept-iles',
#  'sainte-suzanne',
#  'omboue',
#  'uusikaupunki',
#  'waddan',
#  'kutum',
#  'karamea',
#  'tahta',
#  'mata',
#  'bow island',
#  'macaboboni',
#  'leeton',
#  'pechora',
#  'derzhavinsk',
#  'olinda',
#  'hammerfest',
#  'novosineglazovskiy',
#  'palu',
#  'ambulu',
#  'lidzbark warminski',
#  'prosec',
#  'buin',
#  'taltal',
#  'srednekolymsk',
#  'guabito',
#  'hyeres',
#  'haimen',
#  'talesh',
#  'rochegda',
#  'grand centre',
#  'turayf',
#  'krasnyy chikoy',
#  'champerico',
#  'laurel',
#  'umm kaddadah',
#  'mezhdurechenskiy',
#  'aporawan',
#  'staraya toropa',
#  'cahokia',
#  'lata',
#  'azamgarh',
#  'nizhneyansk',
#  'am timan',
#  'mehran',
#  'gura sutii',
#  'laguna',
#  'korla',
#  'santa cruz',
#  'trelew',
#  'broome',
#  'inirida',
#  'warqla',
#  'sao joao dos patos',
#  'uruana',
#  'winnipeg',
#  'takoradi',
#  'benguela',
#  'grand river south east',
#  'scarborough',
#  'rivadavia',
#  'powell river',
#  'lara',
#  'annamalainagar',
#  'inverell',
#  'caravelas',
#  'abalak',
#  'zakamensk',
#  'ngukurr',
#  'awbari',
#  'pacific grove',
#  'mount pleasant',
#  'vanderhoof',
#  'kalga',
#  'palasa',
#  'zyryanka',
#  'hvide sande',
#  'gimli',
#  'sorong',
#  'cairns',
#  'valdivia',
#  'makakilo city',
#  'north bend',
#  'novochernorechenskiy',
#  'laguna de perlas',
#  'djibo',
#  'muros',
#  'honningsvag',
#  'bargal',
#  'enshi',
#  'bivolari',
#  'yenangyaung',
#  'isangel',
#  'adrar',
#  'los llanos de aridane',
#  'mirante do paranapanema',
#  'mergui',
#  'kabare',
#  'parral',
#  'klyuchi',
#  'banjar',
#  'suleya',
#  'medicine hat',
#  'avera',
#  'tilichiki',
#  'sibolga',
#  'boralday',
#  'cap malheureux',
#  'mino',
#  'naerbo',
#  'matara',
#  'itapeva',
#  'zuwarah',
#  'ipixuna',
#  'ayorou',
#  'necochea',
#  'kapoeta',
#  'ajdabiya',
#  'verkhnevilyuysk',
#  'maragogi',
#  'wolmaranstad',
#  'yeppoon',
#  'birin',
#  'dale',
#  'flin flon',
#  'yarmouth',
#  'arrifes',
#  'opoczno',
#  'zhicheng',
#  'abilene',
#  'abu samrah',
#  'chateau-thierry',
#  'staryy biser',
#  'sayyan',
#  'berberati',
#  'marawi',
#  'bonoua',
#  'mahadday weyne',
#  'namibe',
#  'ayan',
#  'hvolsvollur',
#  'susanville',
#  'babushkin',
#  'makkaveyevo',
#  'carbonia',
#  'atasu',
#  'black river',
#  'bandarbeyla',
#  'monrovia',
#  'raga',
#  'roxana',
#  'rumphi',
#  'krasnoselkup',
#  'arman',
#  'manado',
#  'doctor pedro p. pena',
#  'kropotkin',
#  'zumarraga',
#  'kapit',
#  'sarkand',
#  'pocatello',
#  'lubbock',
#  'kurumkan',
#  'kosino',
#  'barlinek',
#  'collie',
#  'mogadishu',
#  'sao joao da barra',
#  'kinsale',
#  'krasnoarmeysk',
#  'svetlyy',
#  'kiama',
#  'correntina',
#  'guantanamo',
#  'port-gentil',
#  'normandin',
#  'shieli',
#  'tabiauea',
#  'karkaralinsk',
#  'calama',
#  'tarancon',
#  'batagay-alyta',
#  'baruun-urt',
#  'ambovombe',
#  'tonantins',
#  'henties bay',
#  'bocas del toro',
#  'nehe',
#  'namwala',
#  'shelburne',
#  'batemans bay',
#  'wakkanai',
#  'tiarei',
#  'auki',
#  'vostok',
#  'faya',
#  'drinovci',
#  'longford',
#  'kilis',
#  'mayo',
#  'casa grande',
#  'lima',
#  'husum',
#  'sampit',
#  'mujiayingzi',
#  'gloversville',
#  'mailani',
#  'bari',
#  'kalangala',
#  'singaparna',
#  'muscat',
#  'glubokiy',
#  'malumfashi',
#  'mahajanga',
#  'kuandian',
#  'progreso',
#  'sibay',
#  'muravlenko',
#  'yekimovichi',
#  'prieska',
#  'kosonsoy',
#  'san pedro',
#  'le port',
#  'ilek',
#  'presidencia roque saenz pena',
#  'kalabo',
#  'zhangjiakou',
#  'prince rupert',
#  'nahan',
#  'lokosovo',
#  'sakaraha',
#  'yumen',
#  'republic',
#  'esna',
#  'karakendzha',
#  'khani',
#  'san ramon',
#  'manama',
#  'sayhat',
#  'horodnytsya',
#  'pundaguitan',
#  'yanchukan',
#  'kristiinankaupunki']

# %%
city_data
# Out:
# [{'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 71.6,
#   'Humidity': 48,
#   'Cloudiness': 31,
#   'Wind Speed': 5.35,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 93,
#   'Wind Speed': 1.99,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 55,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yagunovskiy',
#   'Lat': 55.2828,
#   'Lng': 85.978,
#   'Max Temp': 37.4,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 86,
#   'Humidity': 23,
#   'Cloudiness': 14,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 48.99,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Current Description': 'light rain'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 74.17,
#   'Humidity': 48,
#   'Cloudiness': 5,
#   'Wind Speed': 3.13,
#   'Country': 'TL',
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 44.6,
#   'Humidity': 100,
#   'Cloudiness': 94,
#   'Wind Speed': 1.45,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.02,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 10.56,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 79.03,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 16.31,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Current Description': 'light rain'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 79.99,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.35,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Keflavik',
#   'Lat': 64.0049,
#   'Lng': -22.5624,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IS',
#   'Current Description': 'clear sky'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 82.42,
#   'Humidity': 72,
#   'Cloudiness': 93,
#   'Wind Speed': 5.21,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'Uarini',
#   'Lat': -2.99,
#   'Lng': -65.1083,
#   'Max Temp': 73.87,
#   'Humidity': 95,
#   'Cloudiness': 37,
#   'Wind Speed': 1.66,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 61,
#   'Humidity': 61,
#   'Cloudiness': 78,
#   'Wind Speed': 13,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'TO',
#   'Current Description': 'few clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'CK',
#   'Current Description': 'light rain'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 73.99,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Anta',
#   'Lat': 25.15,
#   'Lng': 76.3,
#   'Max Temp': 82.29,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 9.06,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 71.6,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 70.16,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 16.6,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'VE',
#   'Current Description': 'few clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 59,
#   'Humidity': 23,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Kangaatsiaq',
#   'Lat': 68.3065,
#   'Lng': -53.4641,
#   'Max Temp': 27.37,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Loandjili',
#   'Lat': -4.7561,
#   'Lng': 11.8578,
#   'Max Temp': 77.99,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Country': 'CG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 80.47,
#   'Humidity': 79,
#   'Cloudiness': 95,
#   'Wind Speed': 4.23,
#   'Country': 'PG',
#   'Current Description': 'moderate rain'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 82.4,
#   'Humidity': 32,
#   'Cloudiness': 2,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Yermish',
#   'Lat': 54.7678,
#   'Lng': 42.2711,
#   'Max Temp': 43.21,
#   'Humidity': 94,
#   'Cloudiness': 12,
#   'Wind Speed': 9.13,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 36.57,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.42,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 85.33,
#   'Humidity': 66,
#   'Cloudiness': 39,
#   'Wind Speed': 5.17,
#   'Country': 'SB',
#   'Current Description': 'light rain'},
#  {'City': 'Zatoka',
#   'Lat': 46.0725,
#   'Lng': 30.4654,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'UA',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 31.86,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 15.35,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 63.9,
#   'Humidity': 59,
#   'Cloudiness': 59,
#   'Wind Speed': 6.4,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Martapura',
#   'Lat': -3.4167,
#   'Lng': 114.85,
#   'Max Temp': 86,
#   'Humidity': 54,
#   'Cloudiness': 4,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 60.8,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ngunguru',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 72,
#   'Humidity': 61,
#   'Cloudiness': 2,
#   'Wind Speed': 7,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.37,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Country': 'KI',
#   'Current Description': 'moderate rain'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'haze'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 81.88,
#   'Humidity': 77,
#   'Cloudiness': 15,
#   'Wind Speed': 1.57,
#   'Country': 'LK',
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'RE',
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 44.6,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 24.06,
#   'Humidity': 52,
#   'Cloudiness': 15,
#   'Wind Speed': 5.7,
#   'Country': 'IN',
#   'Current Description': 'few clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 37.4,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 77,
#   'Humidity': 95,
#   'Cloudiness': 16,
#   'Wind Speed': 5.99,
#   'Country': 'EC',
#   'Current Description': 'few clouds'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 86.63,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 8.41,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Ayios Nikolaos',
#   'Lat': 38.4167,
#   'Lng': 23.65,
#   'Max Temp': 57.99,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 4.38,
#   'Country': 'GR',
#   'Current Description': 'light rain'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 53.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Current Description': 'mist'},
#  {'City': 'Acajutla',
#   'Lat': 13.5928,
#   'Lng': -89.8275,
#   'Max Temp': 73.99,
#   'Humidity': 88,
#   'Cloudiness': 12,
#   'Wind Speed': 4,
#   'Country': 'SV',
#   'Current Description': 'few clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 84.65,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 6.82,
#   'Country': 'ID',
#   'Current Description': 'clear sky'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 12.2,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3.71,
#   'Country': 'CA',
#   'Current Description': 'fog'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 35.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 55.99,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 80.76,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 9.64,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 58.98,
#   'Humidity': 76,
#   'Cloudiness': 21,
#   'Wind Speed': 15.39,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 55,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 10.09,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 48.99,
#   'Humidity': 90,
#   'Cloudiness': 88,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 68,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 50.58,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.76,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Esmeraldas',
#   'Lat': -19.7625,
#   'Lng': -44.3139,
#   'Max Temp': 69.8,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Gijon',
#   'Lat': 43.5357,
#   'Lng': -5.6615,
#   'Max Temp': 62.01,
#   'Humidity': 76,
#   'Cloudiness': 56,
#   'Wind Speed': 5.48,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 30.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'GL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 53.01,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Yantzaza',
#   'Lat': -3.8278,
#   'Lng': -78.7594,
#   'Max Temp': 68.58,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.47,
#   'Country': 'EC',
#   'Current Description': 'moderate rain'},
#  {'City': 'Hare Bay',
#   'Lat': 48.8499,
#   'Lng': -54.0148,
#   'Max Temp': 35.6,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 62.11,
#   'Humidity': 96,
#   'Cloudiness': 69,
#   'Wind Speed': 8.12,
#   'Country': 'UY',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 37.4,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Country': 'NO',
#   'Current Description': 'few clouds'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 60.8,
#   'Humidity': 44,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.92,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 15.73,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'San Juan Bautista',
#   'Lat': -14.0108,
#   'Lng': -75.7358,
#   'Max Temp': 66.99,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 15.8,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Massakory',
#   'Lat': 12.996,
#   'Lng': 15.7293,
#   'Max Temp': 88.59,
#   'Humidity': 16,
#   'Cloudiness': 30,
#   'Wind Speed': 9.19,
#   'Country': 'TD',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antropovo',
#   'Lat': 58.3988,
#   'Lng': 43.0066,
#   'Max Temp': 41.45,
#   'Humidity': 91,
#   'Cloudiness': 49,
#   'Wind Speed': 7.11,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.38,
#   'Humidity': 78,
#   'Cloudiness': 23,
#   'Wind Speed': 23.85,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Bologoye',
#   'Lat': 57.8799,
#   'Lng': 34.1068,
#   'Max Temp': 32.97,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qurayyat',
#   'Lat': 31.3318,
#   'Lng': 37.3428,
#   'Max Temp': 71.6,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Zyryanovsk',
#   'Lat': 49.7386,
#   'Lng': 84.2719,
#   'Max Temp': 31.77,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'KZ',
#   'Current Description': 'light snow'},
#  {'City': 'Tsiroanomandidy',
#   'Lat': -18.7667,
#   'Lng': 46.0333,
#   'Max Temp': 61.38,
#   'Humidity': 94,
#   'Cloudiness': 87,
#   'Wind Speed': 3.04,
#   'Country': 'MG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pattani',
#   'Lat': 6.75,
#   'Lng': 100.4167,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'TH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 31.98,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'New Iberia',
#   'Lat': 30.0035,
#   'Lng': -91.8187,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 77,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 84.74,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Marrakesh',
#   'Lat': 31.6315,
#   'Lng': -8.0083,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'MA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 60.01,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mmathubudukwane',
#   'Lat': -24.6,
#   'Lng': 26.4333,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'BW',
#   'Current Description': 'clear sky'},
#  {'City': 'Grand-Santi',
#   'Lat': 4.25,
#   'Lng': -54.3833,
#   'Max Temp': 73.15,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Country': 'GF',
#   'Current Description': 'moderate rain'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'BB',
#   'Current Description': 'few clouds'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 87.84,
#   'Humidity': 23,
#   'Cloudiness': 90,
#   'Wind Speed': 13.51,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 59,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 46.99,
#   'Humidity': 42,
#   'Cloudiness': 2,
#   'Wind Speed': 4.97,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Pohrebyshche',
#   'Lat': 49.4864,
#   'Lng': 29.2636,
#   'Max Temp': 34.29,
#   'Humidity': 83,
#   'Cloudiness': 3,
#   'Wind Speed': 9.17,
#   'Country': 'UA',
#   'Current Description': 'clear sky'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nuoro',
#   'Lat': 40.3211,
#   'Lng': 9.3297,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IT',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 69.8,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 75.99,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 16.84,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.03,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 51.01,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 80.6,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 87.3,
#   'Humidity': 58,
#   'Cloudiness': 31,
#   'Wind Speed': 1.88,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 18.1,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Los Lunas',
#   'Lat': 34.8062,
#   'Lng': -106.7334,
#   'Max Temp': 61,
#   'Humidity': 30,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Traverse City',
#   'Lat': 44.7631,
#   'Lng': -85.6206,
#   'Max Temp': 53.6,
#   'Humidity': 35,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 78.17,
#   'Humidity': 79,
#   'Cloudiness': 3,
#   'Wind Speed': 17.83,
#   'Country': 'TC',
#   'Current Description': 'clear sky'},
#  {'City': 'Arinos',
#   'Lat': -15.9169,
#   'Lng': -46.1056,
#   'Max Temp': 75.85,
#   'Humidity': 54,
#   'Cloudiness': 84,
#   'Wind Speed': 0.31,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Preobrazheniye',
#   'Lat': 42.9019,
#   'Lng': 133.9064,
#   'Max Temp': 56.61,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'AR',
#   'Current Description': 'moderate rain'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 63.52,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 7.56,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Winton',
#   'Lat': 37.3894,
#   'Lng': -120.6133,
#   'Max Temp': 73.4,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Price',
#   'Lat': 39.5994,
#   'Lng': -110.8107,
#   'Max Temp': 55.4,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kita',
#   'Lat': 13.0349,
#   'Lng': -9.4895,
#   'Max Temp': 88.25,
#   'Humidity': 33,
#   'Cloudiness': 80,
#   'Wind Speed': 7.27,
#   'Country': 'ML',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.14,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.96,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 50.94,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barzas',
#   'Lat': 55.7167,
#   'Lng': 86.3167,
#   'Max Temp': 37.4,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 33.26,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 17.18,
#   'Country': 'NO',
#   'Current Description': 'light snow'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 31.96,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 60.01,
#   'Humidity': 80,
#   'Cloudiness': 21,
#   'Wind Speed': 4,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Saveh',
#   'Lat': 35.0213,
#   'Lng': 50.3566,
#   'Max Temp': 65.93,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Country': 'IR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maiduguri',
#   'Lat': 11.8464,
#   'Lng': 13.1603,
#   'Max Temp': 83.41,
#   'Humidity': 14,
#   'Cloudiness': 93,
#   'Wind Speed': 4.79,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 57.81,
#   'Humidity': 77,
#   'Cloudiness': 44,
#   'Wind Speed': 0.74,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'RE',
#   'Current Description': 'moderate rain'},
#  {'City': 'Teluk Nibung',
#   'Lat': 3.001,
#   'Lng': 99.8164,
#   'Max Temp': 76.84,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 52.45,
#   'Humidity': 91,
#   'Cloudiness': 79,
#   'Wind Speed': 7.38,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kubuta',
#   'Lat': -26.8833,
#   'Lng': 31.4833,
#   'Max Temp': 55.6,
#   'Humidity': 87,
#   'Cloudiness': 3,
#   'Wind Speed': 4.05,
#   'Country': 'SZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mendi',
#   'Lat': -6.1761,
#   'Lng': 143.6513,
#   'Max Temp': 65.8,
#   'Humidity': 81,
#   'Cloudiness': 72,
#   'Wind Speed': 4.21,
#   'Country': 'PG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vermilion',
#   'Lat': 40.1667,
#   'Lng': -87.7506,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 59,
#   'Humidity': 21,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batticaloa',
#   'Lat': 7.7102,
#   'Lng': 81.6924,
#   'Max Temp': 81.73,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 1.57,
#   'Country': 'LK',
#   'Current Description': 'clear sky'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 60.01,
#   'Humidity': 87,
#   'Cloudiness': 81,
#   'Wind Speed': 4.47,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 32.23,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.92,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Varna',
#   'Lat': 43.2167,
#   'Lng': 27.9167,
#   'Max Temp': 45,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'BG',
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 27.95,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 71.01,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 62.29,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 7.09,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 78.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Shenkursk',
#   'Lat': 62.1091,
#   'Lng': 42.896,
#   'Max Temp': 45.52,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Blagodatnoye',
#   'Lat': 45.3997,
#   'Lng': 42.5867,
#   'Max Temp': 51.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 66.99,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'PW',
#   'Current Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 79,
#   'Humidity': 80,
#   'Cloudiness': 78,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 33.57,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 20.42,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 19.4,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 80.01,
#   'Humidity': 44,
#   'Cloudiness': 34,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Penzance',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 48.99,
#   'Humidity': 81,
#   'Cloudiness': 64,
#   'Wind Speed': 25.86,
#   'Country': 'GB',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 31.78,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 9.31,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 76.57,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rongcheng',
#   'Lat': 30.634,
#   'Lng': 117.8517,
#   'Max Temp': 67.06,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sovetskaya Gavan',
#   'Lat': 48.9723,
#   'Lng': 140.2878,
#   'Max Temp': 39.72,
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 10.8,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rio De Janeiro',
#   'Lat': -22.9028,
#   'Lng': -43.2075,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 58.64,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 28.74,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 9.88,
#   'Humidity': 85,
#   'Cloudiness': 18,
#   'Wind Speed': 1.41,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 39.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhukovo',
#   'Lat': 55.0318,
#   'Lng': 36.744,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'moderate rain'},
#  {'City': 'Beihai',
#   'Lat': 21.4833,
#   'Lng': 109.1,
#   'Max Temp': 80.28,
#   'Humidity': 81,
#   'Cloudiness': 9,
#   'Wind Speed': 12.26,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 42.8,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 42.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Songjianghe',
#   'Lat': 42.1859,
#   'Lng': 127.479,
#   'Max Temp': 60.19,
#   'Humidity': 51,
#   'Cloudiness': 90,
#   'Wind Speed': 8.12,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 21.2,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 83.64,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 13.42,
#   'Country': 'VU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 89.6,
#   'Humidity': 53,
#   'Cloudiness': 93,
#   'Wind Speed': 8.23,
#   'Country': 'PH',
#   'Current Description': 'moderate rain'},
#  {'City': 'Ust-Maya',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': 28.49,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.45,
#   'Humidity': 70,
#   'Cloudiness': 17,
#   'Wind Speed': 5.1,
#   'Country': 'MV',
#   'Current Description': 'few clouds'},
#  {'City': 'Baherden',
#   'Lat': 38.4362,
#   'Lng': 57.4316,
#   'Max Temp': 65.71,
#   'Humidity': 58,
#   'Cloudiness': 68,
#   'Wind Speed': 4.43,
#   'Country': 'TM',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tevaitoa',
#   'Lat': -16.7833,
#   'Lng': -151.5,
#   'Max Temp': 79.86,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 85.42,
#   'Humidity': 11,
#   'Cloudiness': 6,
#   'Wind Speed': 6.53,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 17.8,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 67.17,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 6.02,
#   'Country': 'YE',
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 38.07,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 6.64,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 29.35,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 5.66,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maldonado',
#   'Lat': -34.6667,
#   'Lng': -54.9167,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 43.48,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.81,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 67.71,
#   'Humidity': 87,
#   'Cloudiness': 3,
#   'Wind Speed': 7.63,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Dvinskoy',
#   'Lat': 62.1535,
#   'Lng': 45.1175,
#   'Max Temp': 46.45,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 8.37,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bendigo',
#   'Lat': -36.7667,
#   'Lng': 144.2833,
#   'Max Temp': 57.99,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gualaca',
#   'Lat': 8.5333,
#   'Lng': -82.3,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'PA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dolores',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 63.5,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Country': 'AR',
#   'Current Description': 'light rain'},
#  {'City': 'Gushikawa',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 78.91,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 11.36,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 36.54,
#   'Humidity': 54,
#   'Cloudiness': 98,
#   'Wind Speed': 21.45,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 86.36,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Brockville',
#   'Lat': 44.5834,
#   'Lng': -75.6826,
#   'Max Temp': 50,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 60.66,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 13.33,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gallup',
#   'Lat': 35.5281,
#   'Lng': -108.7426,
#   'Max Temp': 59,
#   'Humidity': 12,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ahuimanu',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mubi',
#   'Lat': 10.2676,
#   'Lng': 13.2644,
#   'Max Temp': 81.09,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tongzi',
#   'Lat': 28.7829,
#   'Lng': 105.0877,
#   'Max Temp': 72.63,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 8.3,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.8986,
#   'Lng': 122.7617,
#   'Max Temp': 25.68,
#   'Humidity': 81,
#   'Cloudiness': 94,
#   'Wind Speed': 5.73,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.81,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 48,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 78.8,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Kelheim',
#   'Lat': 48.9167,
#   'Lng': 11.8667,
#   'Max Temp': 39.99,
#   'Humidity': 80,
#   'Cloudiness': 14,
#   'Wind Speed': 1.14,
#   'Country': 'DE',
#   'Current Description': 'few clouds'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 59,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 60.01,
#   'Humidity': 94,
#   'Cloudiness': 5,
#   'Wind Speed': 2.3,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 70,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pryazha',
#   'Lat': 61.6926,
#   'Lng': 33.6216,
#   'Max Temp': 30.2,
#   'Humidity': 93,
#   'Cloudiness': 9,
#   'Wind Speed': 4.21,
#   'Country': 'RU',
#   'Current Description': 'mist'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 48.2,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'CO',
#   'Current Description': 'clear sky'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': 25.68,
#   'Humidity': 68,
#   'Cloudiness': 19,
#   'Wind Speed': 6.33,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 89.01,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PH',
#   'Current Description': 'few clouds'},
#  {'City': 'Owando',
#   'Lat': -0.4819,
#   'Lng': 15.8999,
#   'Max Temp': 68.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'CG',
#   'Current Description': 'moderate rain'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 35.4,
#   'Humidity': 89,
#   'Cloudiness': 9,
#   'Wind Speed': 4.29,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 33.35,
#   'Humidity': 82,
#   'Cloudiness': 2,
#   'Wind Speed': 3.8,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 17.6,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'SJ',
#   'Current Description': 'light snow'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.72,
#   'Humidity': 77,
#   'Cloudiness': 61,
#   'Wind Speed': 11.74,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 66.4,
#   'Humidity': 63,
#   'Cloudiness': 21,
#   'Wind Speed': 9.42,
#   'Country': 'NZ',
#   'Current Description': 'few clouds'},
#  {'City': 'Barhi',
#   'Lat': 23.9,
#   'Lng': 80.8,
#   'Max Temp': 87.39,
#   'Humidity': 14,
#   'Cloudiness': 83,
#   'Wind Speed': 8.93,
#   'Country': 'IN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tandil',
#   'Lat': -37.3217,
#   'Lng': -59.1332,
#   'Max Temp': 61,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Current Description': 'light rain'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 53.46,
#   'Humidity': 78,
#   'Cloudiness': 9,
#   'Wind Speed': 3.98,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 70.41,
#   'Humidity': 86,
#   'Cloudiness': 73,
#   'Wind Speed': 3.15,
#   'Country': 'MG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 66.99,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nizwa',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 75.7,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 1.1,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Alta',
#   'Lat': -38.8759,
#   'Lng': -62.0736,
#   'Max Temp': 63.75,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 46.99,
#   'Humidity': 76,
#   'Cloudiness': 86,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 81,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Country': 'GH',
#   'Current Description': 'moderate rain'},
#  {'City': 'Eravur',
#   'Lat': 7.7733,
#   'Lng': 81.6095,
#   'Max Temp': 81.43,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 2.37,
#   'Country': 'LK',
#   'Current Description': 'clear sky'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 32.05,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 5.37,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Finnsnes',
#   'Lat': 69.2296,
#   'Lng': 17.9811,
#   'Max Temp': 28.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
# ...
#  {'City': 'Sarkand',
#   'Lat': 45.41,
#   'Lng': 79.9186,
#   'Max Temp': 32.22,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 7.02,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Pocatello',
#   'Lat': 42.8713,
#   'Lng': -112.4455,
#   'Max Temp': 55.4,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Lubbock',
#   'Lat': 33.6001,
#   'Lng': -101.8338,
#   'Max Temp': 70,
#   'Humidity': 13,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Kurumkan',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 38.23,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kosino',
#   'Lat': 58.4127,
#   'Lng': 51.2782,
#   'Max Temp': 38.48,
#   'Humidity': 93,
#   'Cloudiness': 35,
#   'Wind Speed': 7.23,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barlinek',
#   'Lat': 52.9946,
#   'Lng': 15.2186,
#   'Max Temp': 39,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'PL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Collie',
#   'Lat': -33.3667,
#   'Lng': 116.15,
#   'Max Temp': 75.11,
#   'Humidity': 35,
#   'Cloudiness': 93,
#   'Wind Speed': 5.55,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 82.27,
#   'Humidity': 71,
#   'Cloudiness': 73,
#   'Wind Speed': 7.9,
#   'Country': 'SO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 69.24,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 7.76,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Kinsale',
#   'Lat': 51.7075,
#   'Lng': -8.5306,
#   'Max Temp': 48.2,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'IE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Krasnoarmeysk',
#   'Lat': 51.0239,
#   'Lng': 45.6969,
#   'Max Temp': 44.01,
#   'Humidity': 92,
#   'Cloudiness': 50,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 28.4,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 71.01,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Correntina',
#   'Lat': -13.3433,
#   'Lng': -44.6367,
#   'Max Temp': 75.56,
#   'Humidity': 67,
#   'Cloudiness': 95,
#   'Wind Speed': 0.87,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guantanamo',
#   'Lat': 20.1444,
#   'Lng': -75.2092,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CU',
#   'Current Description': 'few clouds'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 81.01,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Country': 'GA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Normandin',
#   'Lat': 48.8333,
#   'Lng': -72.5321,
#   'Max Temp': 44.6,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Shieli',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 49.8,
#   'Humidity': 30,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 51.8,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Tarancon',
#   'Lat': 40.0085,
#   'Lng': -3.0073,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'ES',
#   'Current Description': 'clear sky'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 17.24,
#   'Humidity': 71,
#   'Cloudiness': 18,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 45.95,
#   'Humidity': 25,
#   'Cloudiness': 99,
#   'Wind Speed': 14.09,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 67.12,
#   'Humidity': 90,
#   'Cloudiness': 2,
#   'Wind Speed': 8.28,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Tonantins',
#   'Lat': -2.8731,
#   'Lng': -67.8022,
#   'Max Temp': 74.25,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 60.01,
#   'Humidity': 93,
#   'Cloudiness': 36,
#   'Wind Speed': 1.99,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bocas Del Toro',
#   'Lat': 9.3333,
#   'Lng': -82.25,
#   'Max Temp': 79.68,
#   'Humidity': 76,
#   'Cloudiness': 55,
#   'Wind Speed': 4.99,
#   'Country': 'PA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nehe',
#   'Lat': 48.4833,
#   'Lng': 124.8333,
#   'Max Temp': 49.55,
#   'Humidity': 18,
#   'Cloudiness': 28,
#   'Wind Speed': 11.32,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namwala',
#   'Lat': -15.7504,
#   'Lng': 26.4384,
#   'Max Temp': 57.79,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3.8,
#   'Country': 'ZM',
#   'Current Description': 'clear sky'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 50,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 66.99,
#   'Humidity': 47,
#   'Cloudiness': 38,
#   'Wind Speed': 5.1,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 84.25,
#   'Humidity': 71,
#   'Cloudiness': 41,
#   'Wind Speed': 3.36,
#   'Country': 'SB',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 35.62,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.9,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Drinovci',
#   'Lat': 43.355,
#   'Lng': 17.3539,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'BA',
#   'Current Description': 'few clouds'},
#  {'City': 'Longford',
#   'Lat': 53.7333,
#   'Lng': -7.8,
#   'Max Temp': 40.8,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'IE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kilis',
#   'Lat': 36.7161,
#   'Lng': 37.115,
#   'Max Temp': 48.2,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'TR',
#   'Current Description': 'clear sky'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 53.01,
#   'Humidity': 63,
#   'Cloudiness': 53,
#   'Wind Speed': 6.82,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Casa Grande',
#   'Lat': 32.8795,
#   'Lng': -111.7573,
#   'Max Temp': 80.6,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Lima',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Husum',
#   'Lat': 54.4858,
#   'Lng': 9.0524,
#   'Max Temp': 41,
#   'Humidity': 87,
#   'Cloudiness': 89,
#   'Wind Speed': 6.91,
#   'Country': 'DE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 87.46,
#   'Humidity': 59,
#   'Cloudiness': 7,
#   'Wind Speed': 2.62,
#   'Country': 'ID',
#   'Current Description': 'clear sky'},
#  {'City': 'Mujiayingzi',
#   'Lat': 42.1167,
#   'Lng': 118.7833,
#   'Max Temp': 50.41,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 11.36,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gloversville',
#   'Lat': 43.0528,
#   'Lng': -74.3438,
#   'Max Temp': 46.4,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Mailani',
#   'Lat': 28.2833,
#   'Lng': 80.35,
#   'Max Temp': 79.88,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 8.61,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Bari',
#   'Lat': 41.1177,
#   'Lng': 16.8512,
#   'Max Temp': 55.99,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 41.43,
#   'Country': 'IT',
#   'Current Description': 'drizzle'},
#  {'City': 'Kalangala',
#   'Lat': -0.3089,
#   'Lng': 32.225,
#   'Max Temp': 70.83,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 14.27,
#   'Country': 'UG',
#   'Current Description': 'moderate rain'},
#  {'City': 'Singaparna',
#   'Lat': -7.3515,
#   'Lng': 108.111,
#   'Max Temp': 79.02,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Country': 'ID',
#   'Current Description': 'clear sky'},
#  {'City': 'Muscat',
#   'Lat': 23.6139,
#   'Lng': 58.5922,
#   'Max Temp': 86,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Glubokiy',
#   'Lat': 48.5217,
#   'Lng': 40.3258,
#   'Max Temp': 49.93,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Malumfashi',
#   'Lat': 11.7853,
#   'Lng': 7.6218,
#   'Max Temp': 81.57,
#   'Humidity': 39,
#   'Cloudiness': 87,
#   'Wind Speed': 7.02,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'MG',
#   'Current Description': 'few clouds'},
#  {'City': 'Kuandian',
#   'Lat': 40.7286,
#   'Lng': 124.7847,
#   'Max Temp': 62.8,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Progreso',
#   'Lat': 21.2833,
#   'Lng': -89.6667,
#   'Max Temp': 87.8,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Sibay',
#   'Lat': 52.7181,
#   'Lng': 58.6658,
#   'Max Temp': 42.55,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 15.66,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muravlenko',
#   'Lat': 63.7898,
#   'Lng': 74.523,
#   'Max Temp': 34.18,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 11.12,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yekimovichi',
#   'Lat': 54.1129,
#   'Lng': 33.2965,
#   'Max Temp': 32.27,
#   'Humidity': 88,
#   'Cloudiness': 21,
#   'Wind Speed': 4.05,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Prieska',
#   'Lat': -29.6641,
#   'Lng': 22.7474,
#   'Max Temp': 64.94,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 6.53,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kosonsoy',
#   'Lat': 41.2561,
#   'Lng': 71.5508,
#   'Max Temp': 55.4,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'UZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 89.01,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PH',
#   'Current Description': 'few clouds'},
#  {'City': 'Le Port',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'RE',
#   'Current Description': 'few clouds'},
#  {'City': 'Ilek',
#   'Lat': 51.5271,
#   'Lng': 53.3831,
#   'Max Temp': 44.76,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 69.03,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalabo',
#   'Lat': -14.97,
#   'Lng': 22.6814,
#   'Max Temp': 64.24,
#   'Humidity': 56,
#   'Cloudiness': 27,
#   'Wind Speed': 4.32,
#   'Country': 'ZM',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 61.74,
#   'Humidity': 50,
#   'Cloudiness': 6,
#   'Wind Speed': 9.19,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Nahan',
#   'Lat': 30.55,
#   'Lng': 77.3,
#   'Max Temp': 69.06,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 2.55,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Lokosovo',
#   'Lat': 61.1333,
#   'Lng': 74.8167,
#   'Max Temp': 37.47,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sakaraha',
#   'Lat': -22.9,
#   'Lng': 44.5333,
#   'Max Temp': 65.82,
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 4.65,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 44.33,
#   'Humidity': 59,
#   'Cloudiness': 95,
#   'Wind Speed': 0.6,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Republic',
#   'Lat': 37.12,
#   'Lng': -93.4802,
#   'Max Temp': 57.2,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Esna',
#   'Lat': 25.2934,
#   'Lng': 32.554,
#   'Max Temp': 73.4,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 53.6,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'GE',
#   'Current Description': 'clear sky'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 57,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Manama',
#   'Lat': 26.2154,
#   'Lng': 50.5832,
#   'Max Temp': 82.4,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'BH',
#   'Current Description': 'clear sky'},
#  {'City': 'Sayhat',
#   'Lat': 26.4852,
#   'Lng': 50.0405,
#   'Max Temp': 73.4,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Horodnytsya',
#   'Lat': 50.807,
#   'Lng': 27.3168,
#   'Max Temp': 34.93,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pundaguitan',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 84.16,
#   'Humidity': 68,
#   'Cloudiness': 52,
#   'Wind Speed': 7.78,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kristiinankaupunki',
#   'Lat': 62.2743,
#   'Lng': 21.376,
#   'Max Temp': 32.58,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 22.1,
#   'Country': 'FI',
#   'Current Description': 'light snow'}]

# %%
city_weather = requests.get(city_url).json()

# %%
city_weather
# Out:
# {'coord': {'lon': 21.376, 'lat': 62.2743},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': 32.58,
#   'feels_like': 20.17,
#   'temp_min': 32.58,
#   'temp_max': 32.58,
#   'pressure': 1008,
#   'humidity': 96,
#   'sea_level': 1008,
#   'grnd_level': 1007},
#  'visibility': 151,
#  'wind': {'speed': 22.1, 'deg': 335, 'gust': 36.6},
#  'snow': {'1h': 0.365},
#  'clouds': {'all': 100},
#  'dt': 1619230724,
#  'sys': {'country': 'FI', 'sunrise': 1619232048, 'sunset': 1619288646},
#  'timezone': 10800,
#  'id': 650769,
#  'name': 'Kristinestad',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     71.60        48          31
# 1     Kruisfontein -34.0033   24.7314     59.00        93          93
# 2         Hermanus -34.4187   19.2345     55.00        90          95
# 3      Yagunovskiy  55.2828   85.9780     37.40        35           0
# 4             Brae  60.3964   -1.3530     44.60        87          90
# 5            Kapaa  22.0752 -159.3190     78.80        65          40
# 6        Kununurra -15.7667  128.7333     86.00        23          14
# 7          Mataura -46.1927  168.8643     48.99        90          99
# 8     San Patricio  28.0170  -97.5169     78.80        89          40
# 9  Bambous Virieux -20.3428   57.7575     77.00        88          75
#
#    Wind Speed Country Current Description
# 0        5.35      AU    scattered clouds
# 1        1.99      ZA     overcast clouds
# 2        1.01      ZA     overcast clouds
# 3       11.18      RU           clear sky
# 4        2.30      GB     overcast clouds
# 5       16.11      US          light rain
# 6       16.11      AU          few clouds
# 7        4.00      NZ     overcast clouds
# 8       17.27      US    scattered clouds
# 9        8.05      MU          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     71.60        48          31
# 1     Kruisfontein      ZA -34.0033   24.7314     59.00        93          93
# 2         Hermanus      ZA -34.4187   19.2345     55.00        90          95
# 3      Yagunovskiy      RU  55.2828   85.9780     37.40        35           0
# 4             Brae      GB  60.3964   -1.3530     44.60        87          90
# 5            Kapaa      US  22.0752 -159.3190     78.80        65          40
# 6        Kununurra      AU -15.7667  128.7333     86.00        23          14
# 7          Mataura      NZ -46.1927  168.8643     48.99        90          99
# 8     San Patricio      US  28.0170  -97.5169     78.80        89          40
# 9  Bambous Virieux      MU -20.3428   57.7575     77.00        88          75
#
#    Wind Speed Current Description
# 0        5.35    scattered clouds
# 1        1.99     overcast clouds
# 2        1.01     overcast clouds
# 3       11.18           clear sky
# 4        2.30     overcast clouds
# 5       16.11          light rain
# 6       16.11          few clouds
# 7        4.00     overcast clouds
# 8       17.27    scattered clouds
# 9        8.05          light rain
